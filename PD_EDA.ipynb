# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc


path = '/Users/jiyoung/Library/Fonts/NanumGothicCoding-Bold.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()

rc('font', family = font_name)

# %%
DEMO = pd.read_csv("/Users/jiyoung/Desktop/대외활동/롯데멤버스/LPOINT_BIG_COMP/LPOINT_BIG_COMP_01_DEMO.csv")
PDDE = pd.read_csv("/Users/jiyoung/Desktop/대외활동/롯데멤버스/LPOINT_BIG_COMP/LPOINT_BIG_COMP_02_PDDE.csv")
COP_U = pd.read_csv("/Users/jiyoung/Desktop/대외활동/롯데멤버스/LPOINT_BIG_COMP/LPOINT_BIG_COMP_03_COP_U.csv")
PD_CLAC = pd.read_csv("/Users/jiyoung/Desktop/대외활동/롯데멤버스/LPOINT_BIG_COMP/LPOINT_BIG_COMP_04_PD_CLAC.csv")
BR = pd.read_csv("/Users/jiyoung/Desktop/대외활동/롯데멤버스/LPOINT_BIG_COMP/LPOINT_BIG_COMP_05_BR.csv")
LPAY = pd.read_csv("/Users/jiyoung/Desktop/대외활동/롯데멤버스/LPOINT_BIG_COMP/LPOINT_BIG_COMP_06_LPAY.csv")
# Out:
# /Users/jiyoung/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## 데이터 생성

# %%
pdde_clac=pd.merge(PDDE,PD_CLAC).merge(DEMO)
pdde_clac
# Out:
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 0        M430112881  A01000001113        1   A01  A010039  PD0290  20210101
# 1        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 2        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 3        M430112881  A01000004946        1   A01  A010039  PD0290  20210101
# 4        M430112881  A01000005297        1   A01  A010039  PD1692  20210101
# ...             ...           ...      ...   ...      ...     ...       ...
# 4381738  M990831120  E06048952027        2   A06      NaN  PD0508  20211024
# 4381739  M990831120  E06049213300        2   A06      NaN  PD0508  20211026
# 4381740  M828090075  E06050917660        2   A06      NaN  PD0508  20211202
# 4381741  M317815845  E06042488774        2   A06      NaN  PD0510  20210623
# 4381742  M712235627  E06045300371        2   A06      NaN  PD0510  20210821
#
# ...

# %%
pdde_clac=pdde_clac.drop(['cop_c', 'br_c', 'zon_hlv'], axis=1)

# %%
pdde_clac_20=pdde_clac[pdde_clac['ages']=='20대']
pdde_clac_30=pdde_clac[pdde_clac['ages']=='30대']
pdde_clac_20
# Out:
#                cust        rct_no  chnl_dv    pd_c     de_dt  de_hr    buy_am  \
# 2401     M542006779  A01000237140        1  PD0290  20210101     17   47400.0
# 2402     M542006779  A01202508733        1  PD0290  20210530     14   19600.0
# 2403     M542006779  A01311080942        1  PD0290  20210818     18  145000.0
# 2404     M542006779  A01222758833        1  PD1181  20210613     14   13500.0
# 2405     M542006779  A01373123496        1  PD1181  20211003     12    2800.0
# ...             ...           ...      ...     ...       ...    ...       ...
# 4381494  M020510636  A05000220595        1  PD0547  20210118     16   29900.0
# 4381512  M412944422  E05000487285        2  PD1672  20210715     17  198000.0
# 4381532  M793609390  E06019927002        2  PD0507  20210322     13    1400.0
# 4381702  M714296943  E06042198358        2  PD0507  20210614     17  100000.0
# 4381734  M871122793  E06044122308        2  PD0508  20210726     21    8000.0
#
# ...

# %%
pdde_clac_30
# Out:
#                cust        rct_no  chnl_dv    pd_c     de_dt  de_hr    buy_am  \
# 477      M900002349  A01000114905        1  PD0290  20210101     15   96000.0
# 478      M900002349  A01068487429        1  PD0290  20210227     17  358000.0
# 479      M900002349  A01068744480        1  PD0290  20210227     17   12000.0
# 480      M900002349  A01191166699        1  PD0290  20210522     14  297000.0
# 481      M900002349  A01230729396        1  PD0290  20210619     16   83000.0
# ...             ...           ...      ...     ...       ...    ...       ...
# 4381737  M990831120  E06048952027        2  PD0508  20211024      1    8500.0
# 4381738  M990831120  E06048952027        2  PD0508  20211024      1    8500.0
# 4381739  M990831120  E06049213300        2  PD0508  20211026     12   17000.0
# 4381740  M828090075  E06050917660        2  PD0508  20211202     11   50000.0
# 4381742  M712235627  E06045300371        2  PD0510  20210821     11   50000.0
#
# ...

# %%
retro20=pdde_clac_20[pdde_clac_20['clac_mcls_nm']=='레토르트']
retro20['pd_nm'].value_counts()
# Out:
# 즉석밥       1020
# 즉석국/찌개     824
# 기타레토르트     727
# 즉석카레짜장     562
# 즉석컵밥       374
# 즉석죽        355
# 즉석스프       229
# 즉석덮밥류      210
# 즉석누룽지       35
# 즉석면류        23
# Name: pd_nm, dtype: int64

# %%
retro30=pdde_clac_30[pdde_clac_30['clac_mcls_nm']=='레토르트']
retro30['pd_nm'].value_counts()
# Out:
# 즉석국/찌개    4488
# 즉석밥       2790
# 즉석카레짜장    2751
# 기타레토르트    1889
# 즉석죽       1782
# 즉석스프      1453
# 즉석컵밥       987
# 즉석덮밥류      674
# 즉석누룽지      271
# 즉석면류       222
# Name: pd_nm, dtype: int64

# %% [markdown]
# ## 레트로트 구매비율(20대, 30대 별)

# %%
slices=retro20['pd_nm'].value_counts()
labels=retro20['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("20대 레트로트 구매분포")
plt.tight_layout()
plt.show()
slices=retro30['pd_nm'].value_counts()
labels=retro30['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("30대 레트로트 구매분포")
plt.tight_layout()
plt.show()

# %% [markdown]
# 20대는 즉석국/찌개, 즉석밥, 즉석카레짜장(3분카레), 즉석덮밥류, 즉석컵밥(햇반컵밥?)을 선호함
# 30대는 즉석카레짜장, 즉석죽, 즉석국/찌개, 즉석컵밥, 즉석밥을 선호함
# 두 집단은 비슷한 선호를 보임

# %% [markdown]
# ## 대용식 구매비율(20대, 30대 별)

# %%
hmr20=pdde_clac_20[pdde_clac_20['clac_hlv_nm']=='대용식']
hmr30=pdde_clac_30[pdde_clac_30['clac_hlv_nm']=='대용식']

# %%
slices=hmr20['pd_nm'].value_counts()
labels=hmr20['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("20대 대용식 구매분포")
plt.tight_layout()
plt.show()
slices=hmr30['pd_nm'].value_counts()
labels=hmr30['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("30대 대용식 구매분포")
plt.tight_layout()
plt.show()

# %% [markdown]
# 20대는 빵, 컵라면, 비빔컵라면, 파스타류, 라면 선호 >> 봉지라면 보다 컵라면을 더 선호하는 것이 특징
# 30대는 빵, 즉석카레짜장, 즉석죽, 즉석국.찌개 선호 >>라면 보다 밥류 선호, 라면도 봉지라면 선호(국물컵라면 제외)

# %% [markdown]
# ## 냉장식품 구매비율(20대, 30대 별)

# %%
refri20=pdde_clac_20[pdde_clac_20['clac_hlv_nm']=='냉장식품']
refri30=pdde_clac_30[pdde_clac_30['clac_hlv_nm']=='냉장식품']

# %%
slices=refri20['pd_nm'].value_counts()
labels=refri20['pd_nm'].unique()

plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("20대 냉장식품 구매분포")
plt.tight_layout()
plt.show()
slices=refri30['pd_nm'].value_counts()
labels=refri30['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("30대 냉장식품 구매분포")
plt.tight_layout()
plt.show()

# %% [markdown]
# 20대는 냉장과일야채음료, 빵, 냉장치킨족발류, 베이컨, 냉장떡, 어묵 선호(다소 패스트푸드)
# 30대는 어묵, 냉장간편식, 햄, 무침반찬, 조림반찬, 볶음반찬 등 집밥 선호?

# %% [markdown]
# ## 냉동식품 구매비율(20대, 30대 별)

# %%
frozen20=pdde_clac_20[pdde_clac_20['clac_hlv_nm']=='냉동식품']
frozen30=pdde_clac_30[pdde_clac_30['clac_hlv_nm']=='냉동식품']

# %%
slices=frozen20['pd_nm'].value_counts()
labels=frozen20['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("20대 냉동식품 구매분포")
plt.tight_layout()
plt.show()
slices=frozen30['pd_nm'].value_counts()
labels=frozen30['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("30대 냉동식품 구매분포")
plt.tight_layout()
plt.show()

# %% [markdown]
# 20대는 냉동만두, 냉동디저트, 냉동간편식, 튀김, 피자, 아이스크림 선호
# 30대는 아이스크림, 얼음, 만두, 디저트 선호 >> 30대가 20대 보다 밥보다는 디저트류 선호, 즉 냉동식품 간편식을 20대가 더 구매

# %% [markdown]
# ## 조리식품 구매비율(20대, 30대 별)

# %%
food20=pdde_clac_20[pdde_clac_20['clac_hlv_nm']=='조리식품']
food30=pdde_clac_30[pdde_clac_30['clac_hlv_nm']=='조리식품']

# %%
slices=food20['pd_nm'].value_counts()
labels=food20['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("20대 조리식품 구매분포")
plt.tight_layout()
plt.show()
slices=food30['pd_nm'].value_counts()
labels=food30['pd_nm'].unique()
plt.pie(slices,labels=labels,autopct='%1.2f%%')
plt.title("30대 조리식품 구매분포")
plt.tight_layout()
plt.show()

# %% [markdown]
# 20대는 햄버거, 김밥, 빵류 선호 / 30대는 떡, 샌드위치 선호 >>20대가 30대 보다 밥류 구매

# %% [markdown]
# 분석 인사이트
# - 20대와 30대가 구매하는 상품이 차이가 존재함. 현재 보유 데이터가 30대 비율이 많기 때문에 타겟을 2030대로 묶어버리면 30대 위주로 결과가 나올 수 있기 때문에 분리해서 분석해야 한다고 판단.
# Mz세대가 정의로는 2030대긴 하지만, 보통 20대를 지칭하는 것이기에 타겟을 20대로 좁히는게 나을 것 같음.
#
# - 20대는 마트에서 주로 밥류를 구매, 패스트푸드나 요리가 간단한 음식 다수>>자취 영향?
# - 30대는 마트에서 집밥 구매 다수(반찬류 등), 또한 냉동식품코너에서 간편식보다는 아이스크림을 많이 구매한 것을 보다 냉동간편식보다는 디저트류를 더 선호
# -🛑우려할 점: 구매 개수만 세었던 거라 아이스크림이 상대적으로 한 번에 사는 개수가 많아서 그런 걸 수도 있음.
#
# - 20대에 냉장떡 구매가 많은 편인데 떡을 토핑으로 많이 넣나? 연관분석 가능할 수도
